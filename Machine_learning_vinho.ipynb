# %% [markdown]
# # **Criando um modelo de Machine Learning para classificação de vinho**

# %%
# importando os dados
import pandas as pd

arquivo = pd.read_csv("/content/wine_dataset.csv")

# %%
arquivo.head(3)
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
#
#    alcohol  quality style
# 0      9.4        5   red
# 1      9.8        5   red
# 2      9.8        5   red

# %%
# Exibe o numero de linhas e colunas
arquivo.shape
# Out:
# (6497, 13)

# %%
# substituindo os dados da coluna Style por 0 e 1
arquivo['style'] = arquivo['style'].replace('red', 0)

# %%
arquivo['style'] = arquivo['style'].replace('white', 1)

# %% [markdown]
# ### Separando as variaveis entre preditoras e variavel alvo

# %%
y = arquivo['style']
x = arquivo.drop('style', axis=1)

# %%
from sklearn.model_selection import train_test_split

# criando o conjunto de dados de treino e teste
x_treino, x_teste, y_treino, y_teste = train_test_split(x,y, test_size = 0.3)

# %%
from sklearn.ensemble import ExtraTreesClassifier

# criação do modelo

modelo = ExtraTreesClassifier()
modelo.fit(x_treino, y_treino)
# Out:
# ExtraTreesClassifier()

# %%
# imprimindo resultados

resultado = modelo.score(x_teste,y_teste)
print("Acuracia: ", resultado)
# Out:
# Acuracia:  0.9994871794871795

# %%
# verifica os dados a ser previsto por nosso modelo
y_teste[400:403]
# Out:
# 2485    1
# 4967    1
# 4945    1
# Name: style, dtype: int64

# %%
# dados que vamos usar para fazer a predição
x_teste[400:403]
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 2485            7.3              0.26         0.31             1.6      0.040
# 4967            6.6              0.18         0.28             1.7      0.041
# 4945            6.7              0.18         0.24            10.3      0.057
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 2485                 39.0                 173.0  0.99180  3.19       0.51
# 4967                 53.0                 161.0  0.99207  3.13       0.45
# 4945                 64.0                 185.0  0.99519  3.12       0.50
#
#       alcohol  quality
# 2485     11.4        6
# 4967     10.2        6
# 4945     10.6        6

# %%
# fazendo a predição
previsoes = modelo.predict(x_teste[400:403])
previsoes
# Out:
# array([1, 1, 1])
